# %%
from pybaseball import statcast
import pandas as pd
pd.set_option('display.max_columns', 50)
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# Define the date range for the MLB 2022 season
start_date = '2022-04-07'
end_date = '2022-10-05'  # Adjust this date based on the end of the season

# Retrieve Statcast data for the specified date range
statcast_data = statcast(start_dt=start_date, end_dt=end_date)
# Out:
# This is a large query, it may take a moment to complete
# c:\users\siddh\appdata\local\programs\python\python38\lib\site-packages\pybaseball\statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 182/182 [01:26<00:00,  2.10it/s]

# %%
drop_cols = ['release_speed', 'release_pos_x','release_pos_z', 'spin_dir', 
             'spin_rate_deprecated','break_angle_deprecated', 'break_length_deprecated', 
             'zone', 'des', 'game_type','hit_location', 'bb_type', 'pfx_x',
             'pfx_z', 'plate_x', 'plate_z', 'hc_x', 'hc_y',
             'tfs_deprecated', 'tfs_zulu_deprecated',
             'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
             'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
             'release_spin_rate', 'release_extension', 'release_pos_y',
             'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle',
             'woba_value', 'woba_denom', 'babip_value', 'iso_value',
             'launch_speed_angle', 'post_away_score',
             'post_home_score', 'post_bat_score', 'post_fld_score', 'spin_axis',
             'delta_home_win_exp', 'delta_run_exp']
statcast_data = statcast_data.drop(columns=drop_cols)

# %%
statcast_data = statcast_data.iloc[::-1]

# %%
statcast_data
# Out:
#      pitch_type  game_date     player_name  batter  pitcher     events  \
# 1963         FF 2022-04-07  Ohtani, Shohei  514888   660271        NaN
# 1913         FF 2022-04-07  Ohtani, Shohei  514888   660271        NaN
# 1874         FF 2022-04-07  Ohtani, Shohei  514888   660271        NaN
# 1771         ST 2022-04-07  Ohtani, Shohei  514888   660271        NaN
# 1715         FS 2022-04-07  Ohtani, Shohei  514888   660271  strikeout
# ...         ...        ...             ...     ...      ...        ...
# 3749         SL 2022-10-05    Baker, Bryan  643376   641329        NaN
# 3648         FF 2022-10-05    Baker, Bryan  643376   641329        NaN
# 3442         CH 2022-10-05    Baker, Bryan  643376   641329        NaN
# 3293         FF 2022-10-05    Baker, Bryan  643376   641329  strikeout
# 3200         CH 2022-10-05    Baker, Bryan  624415   641329  field_out
#
#           description stand p_throws home_team away_team type  balls  strikes  \
# 1963             ball     R        R       LAA       HOU    B      0        0
# 1913    called_strike     R        R       LAA       HOU    S      1        0
# 1874             ball     R        R       LAA       HOU    B      1        1
# 1771    called_strike     R        R       LAA       HOU    S      2        1
# 1715    called_strike     R        R       LAA       HOU    S      2        2
# ...               ...   ...      ...       ...       ...  ...    ...      ...
# 3749    called_strike     R        R       BAL       TOR    S      1        0
# 3648  swinging_strike     R        R       BAL       TOR    S      1        1
# 3442             ball     R        R       BAL       TOR    B      1        2
# 3293  swinging_strike     R        R       BAL       TOR    S      2        2
# 3200    hit_into_play     L        R       BAL       TOR    X      0        0
#
#       game_year  on_3b  on_2b  on_1b  outs_when_up  inning inning_topbot  \
# 1963       2022   <NA>   <NA>   <NA>             0       1           Top
# 1913       2022   <NA>   <NA>   <NA>             0       1           Top
# 1874       2022   <NA>   <NA>   <NA>             0       1           Top
# 1771       2022   <NA>   <NA>   <NA>             0       1           Top
# 1715       2022   <NA>   <NA>   <NA>             0       1           Top
# ...         ...    ...    ...    ...           ...     ...           ...
# 3749       2022   <NA>   <NA>   <NA>             1       9           Top
# 3648       2022   <NA>   <NA>   <NA>             1       9           Top
# 3442       2022   <NA>   <NA>   <NA>             1       9           Top
# 3293       2022   <NA>   <NA>   <NA>             1       9           Top
# 3200       2022   <NA>   <NA>   <NA>             2       9           Top
#
#       fielder_2  umpire  sv_id  game_pk  pitcher.1  fielder_2.1  fielder_3  \
# 1963     545358    <NA>   <NA>   661042     660271       545358     665120
# 1913     545358    <NA>   <NA>   661042     660271       545358     665120
# 1874     545358    <NA>   <NA>   661042     660271       545358     665120
# 1771     545358    <NA>   <NA>   661042     660271       545358     665120
# 1715     545358    <NA>   <NA>   661042     660271       545358     665120
# ...         ...     ...    ...      ...        ...          ...        ...
# 3749     668939    <NA>   <NA>   663451     641329       668939     663624
# 3648     668939    <NA>   <NA>   663451     641329       668939     663624
# 3442     668939    <NA>   <NA>   663451     641329       668939     663624
# 3293     668939    <NA>   <NA>   663451     641329       668939     663624
# 3200     668939    <NA>   <NA>   663451     641329       668939     663624
#
#       fielder_4  fielder_5  fielder_6  fielder_7  fielder_8  fielder_9  \
# 1963     622110     543685     664058     666176     545361     669016
# 1913     622110     543685     664058     666176     545361     669016
# 1874     622110     543685     664058     666176     545361     669016
# 1771     622110     543685     664058     666176     545361     669016
# 1715     622110     543685     664058     666176     545361     669016
# ...         ...        ...        ...        ...        ...        ...
# 3749     679631     683002     622761     663630     656775     669720
# 3648     679631     683002     622761     663630     656775     669720
# 3442     679631     683002     622761     663630     656775     669720
# 3293     679631     683002     622761     663630     656775     669720
# 3200     679631     683002     622761     663630     656775     669720
#
#       at_bat_number  pitch_number       pitch_name  home_score  away_score  \
# 1963              1             1  4-Seam Fastball           0           0
# 1913              1             2  4-Seam Fastball           0           0
# 1874              1             3  4-Seam Fastball           0           0
# 1771              1             4          Sweeper           0           0
# 1715              1             5     Split-Finger           0           0
# ...             ...           ...              ...         ...         ...
# 3749             77             2           Slider           5           4
# 3648             77             3  4-Seam Fastball           5           4
# 3442             77             4         Changeup           5           4
# 3293             77             5  4-Seam Fastball           5           4
# 3200             78             1         Changeup           5           4
#
#       bat_score  fld_score if_fielding_alignment of_fielding_alignment
# 1963          0          0              Standard              Standard
# 1913          0          0              Standard              Standard
# 1874          0          0              Standard              Standard
# 1771          0          0              Standard              Standard
# 1715          0          0              Standard              Standard
# ...         ...        ...                   ...                   ...
# 3749          4          5              Standard              Standard
# 3648          4          5              Standard              Standard
# 3442          4          5              Standard              Standard
# 3293          4          5              Standard              Standard
# 3200          4          5         Infield shift              Standard
#
# [708540 rows x 43 columns]

# %%
statcast_data.columns
# Out:
# Index(['pitch_type', 'game_date', 'player_name', 'batter', 'pitcher', 'events',
#        'description', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'balls', 'strikes', 'game_year', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'fielder_2', 'umpire',
#        'sv_id', 'game_pk', 'pitcher.1', 'fielder_2.1', 'fielder_3',
#        'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8',
#        'fielder_9', 'at_bat_number', 'pitch_number', 'pitch_name',
#        'home_score', 'away_score', 'bat_score', 'fld_score',
#        'if_fielding_alignment', 'of_fielding_alignment'],
#       dtype='object')

# %%
statcast_data
# Out:
#      pitch_type  game_date     player_name  batter  pitcher     events  \
# 1963         FF 2022-04-07  Ohtani, Shohei  514888   660271        NaN
# 1913         FF 2022-04-07  Ohtani, Shohei  514888   660271        NaN
# 1874         FF 2022-04-07  Ohtani, Shohei  514888   660271        NaN
# 1771         ST 2022-04-07  Ohtani, Shohei  514888   660271        NaN
# 1715         FS 2022-04-07  Ohtani, Shohei  514888   660271  strikeout
# ...         ...        ...             ...     ...      ...        ...
# 3749         SL 2022-10-05    Baker, Bryan  643376   641329        NaN
# 3648         FF 2022-10-05    Baker, Bryan  643376   641329        NaN
# 3442         CH 2022-10-05    Baker, Bryan  643376   641329        NaN
# 3293         FF 2022-10-05    Baker, Bryan  643376   641329  strikeout
# 3200         CH 2022-10-05    Baker, Bryan  624415   641329  field_out
#
#           description stand p_throws home_team away_team type  balls  strikes  \
# 1963             ball     R        R       LAA       HOU    B      0        0
# 1913    called_strike     R        R       LAA       HOU    S      1        0
# 1874             ball     R        R       LAA       HOU    B      1        1
# 1771    called_strike     R        R       LAA       HOU    S      2        1
# 1715    called_strike     R        R       LAA       HOU    S      2        2
# ...               ...   ...      ...       ...       ...  ...    ...      ...
# 3749    called_strike     R        R       BAL       TOR    S      1        0
# 3648  swinging_strike     R        R       BAL       TOR    S      1        1
# 3442             ball     R        R       BAL       TOR    B      1        2
# 3293  swinging_strike     R        R       BAL       TOR    S      2        2
# 3200    hit_into_play     L        R       BAL       TOR    X      0        0
#
#       game_year  on_3b  on_2b  on_1b  outs_when_up  inning inning_topbot  \
# 1963       2022   <NA>   <NA>   <NA>             0       1           Top
# 1913       2022   <NA>   <NA>   <NA>             0       1           Top
# 1874       2022   <NA>   <NA>   <NA>             0       1           Top
# 1771       2022   <NA>   <NA>   <NA>             0       1           Top
# 1715       2022   <NA>   <NA>   <NA>             0       1           Top
# ...         ...    ...    ...    ...           ...     ...           ...
# 3749       2022   <NA>   <NA>   <NA>             1       9           Top
# 3648       2022   <NA>   <NA>   <NA>             1       9           Top
# 3442       2022   <NA>   <NA>   <NA>             1       9           Top
# 3293       2022   <NA>   <NA>   <NA>             1       9           Top
# 3200       2022   <NA>   <NA>   <NA>             2       9           Top
#
#       fielder_2  umpire  sv_id  game_pk  pitcher.1  fielder_2.1  fielder_3  \
# 1963     545358    <NA>   <NA>   661042     660271       545358     665120
# 1913     545358    <NA>   <NA>   661042     660271       545358     665120
# 1874     545358    <NA>   <NA>   661042     660271       545358     665120
# 1771     545358    <NA>   <NA>   661042     660271       545358     665120
# 1715     545358    <NA>   <NA>   661042     660271       545358     665120
# ...         ...     ...    ...      ...        ...          ...        ...
# 3749     668939    <NA>   <NA>   663451     641329       668939     663624
# 3648     668939    <NA>   <NA>   663451     641329       668939     663624
# 3442     668939    <NA>   <NA>   663451     641329       668939     663624
# 3293     668939    <NA>   <NA>   663451     641329       668939     663624
# 3200     668939    <NA>   <NA>   663451     641329       668939     663624
#
#       fielder_4  fielder_5  fielder_6  fielder_7  fielder_8  fielder_9  \
# 1963     622110     543685     664058     666176     545361     669016
# 1913     622110     543685     664058     666176     545361     669016
# 1874     622110     543685     664058     666176     545361     669016
# 1771     622110     543685     664058     666176     545361     669016
# 1715     622110     543685     664058     666176     545361     669016
# ...         ...        ...        ...        ...        ...        ...
# 3749     679631     683002     622761     663630     656775     669720
# 3648     679631     683002     622761     663630     656775     669720
# 3442     679631     683002     622761     663630     656775     669720
# 3293     679631     683002     622761     663630     656775     669720
# 3200     679631     683002     622761     663630     656775     669720
#
#       at_bat_number  pitch_number       pitch_name  home_score  away_score  \
# 1963              1             1  4-Seam Fastball           0           0
# 1913              1             2  4-Seam Fastball           0           0
# 1874              1             3  4-Seam Fastball           0           0
# 1771              1             4          Sweeper           0           0
# 1715              1             5     Split-Finger           0           0
# ...             ...           ...              ...         ...         ...
# 3749             77             2           Slider           5           4
# 3648             77             3  4-Seam Fastball           5           4
# 3442             77             4         Changeup           5           4
# 3293             77             5  4-Seam Fastball           5           4
# 3200             78             1         Changeup           5           4
#
#       bat_score  fld_score if_fielding_alignment of_fielding_alignment
# 1963          0          0              Standard              Standard
# 1913          0          0              Standard              Standard
# 1874          0          0              Standard              Standard
# 1771          0          0              Standard              Standard
# 1715          0          0              Standard              Standard
# ...         ...        ...                   ...                   ...
# 3749          4          5              Standard              Standard
# 3648          4          5              Standard              Standard
# 3442          4          5              Standard              Standard
# 3293          4          5              Standard              Standard
# 3200          4          5         Infield shift              Standard
#
# [708540 rows x 43 columns]

# %%
second_drop_cols = ['on_3b','on_2b','on_1b','umpire','sv_id','fielder_2.1', 
                    'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6', 'fielder_7', 
                    'fielder_8', 'fielder_9', 'if_fielding_alignment', 'of_fielding_alignment']
statcast_data = statcast_data.drop(columns=second_drop_cols)

# %%
statcast_data_grouped = statcast_data.groupby(['game_pk','pitcher','at_bat_number','pitch_number'], dropna=False).first()

# Initialize an empty list to store pitch sequences
pitch_sequences = []
# Initialize an empty string to store the current pitch sequence
current_sequence = []
statcast_data_grouped['pitch_sequence'] = None

# Iterate through the DataFrame rows
for _, row in statcast_data_grouped.iterrows():
    pitch = row['pitch_type']
    event = row['events']
    #print(pitch, event)
    
    # If the event is not 'None', it indicates the end of an at-bat
    if event != None:
        # Append the current pitch sequence to the list
        current_sequence.append(pitch)
        pitch_sequences.append(current_sequence)
        #print(current_sequence)
        statcast_data_grouped.at[_,'pitch_sequence'] = current_sequence
        
        # Reset the current sequence to an empty list
        current_sequence = []
    else:
        # Add the pitch to the current sequence
        current_sequence.append(pitch)

# Append the last pitch sequence (if any) to the list
#if current_sequence:
#    pitch_sequences.append(current_sequence)
    
#statcast_data_grouped = statcast_data_grouped.groupby(['game_date','pitcher','at_bat_number']).first()
#statcast_data_grouped['pitch_sequence'] = pitch_sequences
statcast_data_grouped = statcast_data_grouped[statcast_data_grouped['events']=='strikeout'].reset_index()
statcast_data_grouped
# Out:
#        game_pk  pitcher  at_bat_number  pitch_number pitch_type  game_date  \
# 0       661032   571901             54             6         SI 2022-04-26
# 1       661032   628452             63             4         SL 2022-04-26
# 2       661032   628452             64             5         FF 2022-04-26
# 3       661032   660853             52             7         FF 2022-04-26
# 4       661032   663474              6             5         SL 2022-04-26
# ...        ...      ...            ...           ...        ...        ...
# 40686   663463   669145             11             5         SL 2022-05-03
# 40687   663463   669145             12             6         SL 2022-05-03
# 40688   663463   669145             18             4         CU 2022-05-03
# 40689   663463   669211             64             6         FF 2022-05-03
# 40690   663463   669211             65             8         SL 2022-05-03
#
#                 player_name  batter     events      description stand  \
# 0               Loup, Aaron  595978  strikeout    called_strike     R
# 1          Iglesias, Raisel  614177  strikeout    called_strike     R
# 2          Iglesias, Raisel  680911  strikeout  swinging_strike     R
# 3      De Los Santos, Enyel  621493  strikeout  swinging_strike     R
# 4         McKenzie, Triston  545361  strikeout    called_strike     R
# ...                     ...     ...        ...              ...   ...
# 40686     Zimmermann, Bruce  596142  strikeout  swinging_strike     R
# 40687     Zimmermann, Bruce  596146  strikeout    called_strike     L
# 40688     Zimmermann, Bruce  665482  strikeout    called_strike     R
# 40689          Akin, Keegan  596142  strikeout         foul_tip     R
# 40690          Akin, Keegan  663616  strikeout  swinging_strike     L
#
#       p_throws home_team away_team type  balls  strikes  game_year  \
# 0            L       LAA       CLE    S      2        2       2022
# 1            R       LAA       CLE    S      1        2       2022
# 2            R       LAA       CLE    S      1        2       2022
# 3            R       LAA       CLE    S      3        2       2022
# 4            R       LAA       CLE    S      1        2       2022
# ...        ...       ...       ...  ...    ...      ...        ...
# 40686        L       BAL       MIN    S      1        2       2022
# 40687        L       BAL       MIN    S      2        2       2022
# 40688        L       BAL       MIN    S      1        2       2022
# 40689        L       BAL       MIN    S      0        2       2022
# 40690        L       BAL       MIN    S      3        2       2022
#
#        outs_when_up  inning inning_topbot  fielder_2  pitcher.1  \
# 0                 1       8           Top     435559     571901
# 1                 1       9           Top     435559     628452
# 2                 2       9           Top     435559     628452
# 3                 2       7           Bot     595978     660853
# 4                 2       1           Bot     595978     663474
# ...             ...     ...           ...        ...        ...
# 40686             1       2           Top     621532     669145
# 40687             2       2           Top     621532     669145
# 40688             1       3           Top     621532     669145
# 40689             0       8           Top     621532     669211
# 40690             1       8           Top     621532     669211
#
#             pitch_name  home_score  away_score  bat_score  fld_score  \
# 0               Sinker           4           0          0          4
# 1               Slider           4           1          1          4
# 2      4-Seam Fastball           4           1          1          4
# 3      4-Seam Fastball           4           0          4          0
# 4               Slider           0           0          0          0
# ...                ...         ...         ...        ...        ...
# 40686           Slider           0           0          0          0
# 40687           Slider           0           0          0          0
# 40688        Curveball           0           0          0          0
# 40689  4-Seam Fastball           2           5          5          2
# 40690           Slider           2           5          5          2
#
#                          pitch_sequence
# 0              [FC, FC, SI, SI, FC, SI]
# 1                      [FF, FF, SL, SL]
# 2                  [SL, SL, FF, CH, FF]
# 3          [FF, SL, SL, FF, FF, SL, FF]
# 4                  [FF, FF, SL, FF, SL]
# ...                                 ...
# 40686              [FF, CH, FF, CH, SL]
# 40687          [SL, FF, FF, SL, FF, SL]
# 40688                  [CU, CH, CH, CU]
# 40689          [SL, SL, FF, FF, CH, FF]
# 40690  [SL, SL, FF, FF, SL, SL, SL, SL]
#
# [40691 rows x 29 columns]

# %%
statcast_data[(statcast_data['game_pk']==661032) & (statcast_data['pitcher']==628452)]
# Out:
#      pitch_type  game_date       player_name  batter  pitcher     events  \
# 4455         FF 2022-04-26  Iglesias, Raisel  614177   628452        NaN
# 4368         FF 2022-04-26  Iglesias, Raisel  614177   628452        NaN
# 4155         SL 2022-04-26  Iglesias, Raisel  614177   628452        NaN
# 4065         SL 2022-04-26  Iglesias, Raisel  614177   628452  strikeout
# 3941         SL 2022-04-26  Iglesias, Raisel  680911   628452        NaN
# 3743         SL 2022-04-26  Iglesias, Raisel  680911   628452        NaN
# 3650         FF 2022-04-26  Iglesias, Raisel  680911   628452        NaN
# 3543         CH 2022-04-26  Iglesias, Raisel  680911   628452        NaN
# 3408         FF 2022-04-26  Iglesias, Raisel  680911   628452  strikeout
#
#           description stand p_throws home_team away_team type  balls  strikes  \
# 4455             ball     R        R       LAA       CLE    B      0        0
# 4368    called_strike     R        R       LAA       CLE    S      1        0
# 4155    called_strike     R        R       LAA       CLE    S      1        1
# 4065    called_strike     R        R       LAA       CLE    S      1        2
# 3941             foul     R        R       LAA       CLE    S      0        0
# 3743             ball     R        R       LAA       CLE    B      0        1
# 3650  swinging_strike     R        R       LAA       CLE    S      1        1
# 3543             foul     R        R       LAA       CLE    S      1        2
# 3408  swinging_strike     R        R       LAA       CLE    S      1        2
#
#       game_year  outs_when_up  inning inning_topbot  fielder_2  game_pk  \
# 4455       2022             1       9           Top     435559   661032
# 4368       2022             1       9           Top     435559   661032
# 4155       2022             1       9           Top     435559   661032
# 4065       2022             1       9           Top     435559   661032
# 3941       2022             2       9           Top     435559   661032
# 3743       2022             2       9           Top     435559   661032
# 3650       2022             2       9           Top     435559   661032
# 3543       2022             2       9           Top     435559   661032
# 3408       2022             2       9           Top     435559   661032
#
#       pitcher.1  at_bat_number  pitch_number       pitch_name  home_score  \
# 4455     628452             63             1  4-Seam Fastball           4
# 4368     628452             63             2  4-Seam Fastball           4
# 4155     628452             63             3           Slider           4
# 4065     628452             63             4           Slider           4
# 3941     628452             64             1           Slider           4
# 3743     628452             64             2           Slider           4
# 3650     628452             64             3  4-Seam Fastball           4
# 3543     628452             64             4         Changeup           4
# 3408     628452             64             5  4-Seam Fastball           4
#
#       away_score  bat_score  fld_score
# 4455           1          1          4
# 4368           1          1          4
# 4155           1          1          4
# 4065           1          1          4
# 3941           1          1          4
# 3743           1          1          4
# 3650           1          1          4
# 3543           1          1          4
# 3408           1          1          4

# %%
statcast_data_grouped
# Out:
#        game_pk  pitcher  at_bat_number  pitch_number pitch_type  game_date  \
# 0       661032   571901             54             6         SI 2022-04-26
# 1       661032   628452             63             4         SL 2022-04-26
# 2       661032   628452             64             5         FF 2022-04-26
# 3       661032   660853             52             7         FF 2022-04-26
# 4       661032   663474              6             5         SL 2022-04-26
# ...        ...      ...            ...           ...        ...        ...
# 40686   663463   669145             11             5         SL 2022-05-03
# 40687   663463   669145             12             6         SL 2022-05-03
# 40688   663463   669145             18             4         CU 2022-05-03
# 40689   663463   669211             64             6         FF 2022-05-03
# 40690   663463   669211             65             8         SL 2022-05-03
#
#                 player_name  batter     events      description stand  \
# 0               Loup, Aaron  595978  strikeout    called_strike     R
# 1          Iglesias, Raisel  614177  strikeout    called_strike     R
# 2          Iglesias, Raisel  680911  strikeout  swinging_strike     R
# 3      De Los Santos, Enyel  621493  strikeout  swinging_strike     R
# 4         McKenzie, Triston  545361  strikeout    called_strike     R
# ...                     ...     ...        ...              ...   ...
# 40686     Zimmermann, Bruce  596142  strikeout  swinging_strike     R
# 40687     Zimmermann, Bruce  596146  strikeout    called_strike     L
# 40688     Zimmermann, Bruce  665482  strikeout    called_strike     R
# 40689          Akin, Keegan  596142  strikeout         foul_tip     R
# 40690          Akin, Keegan  663616  strikeout  swinging_strike     L
#
#       p_throws home_team away_team type  balls  strikes  game_year  \
# 0            L       LAA       CLE    S      2        2       2022
# 1            R       LAA       CLE    S      1        2       2022
# 2            R       LAA       CLE    S      1        2       2022
# 3            R       LAA       CLE    S      3        2       2022
# 4            R       LAA       CLE    S      1        2       2022
# ...        ...       ...       ...  ...    ...      ...        ...
# 40686        L       BAL       MIN    S      1        2       2022
# 40687        L       BAL       MIN    S      2        2       2022
# 40688        L       BAL       MIN    S      1        2       2022
# 40689        L       BAL       MIN    S      0        2       2022
# 40690        L       BAL       MIN    S      3        2       2022
#
#        outs_when_up  inning inning_topbot  fielder_2  pitcher.1  \
# 0                 1       8           Top     435559     571901
# 1                 1       9           Top     435559     628452
# 2                 2       9           Top     435559     628452
# 3                 2       7           Bot     595978     660853
# 4                 2       1           Bot     595978     663474
# ...             ...     ...           ...        ...        ...
# 40686             1       2           Top     621532     669145
# 40687             2       2           Top     621532     669145
# 40688             1       3           Top     621532     669145
# 40689             0       8           Top     621532     669211
# 40690             1       8           Top     621532     669211
#
#             pitch_name  home_score  away_score  bat_score  fld_score  \
# 0               Sinker           4           0          0          4
# 1               Slider           4           1          1          4
# 2      4-Seam Fastball           4           1          1          4
# 3      4-Seam Fastball           4           0          4          0
# 4               Slider           0           0          0          0
# ...                ...         ...         ...        ...        ...
# 40686           Slider           0           0          0          0
# 40687           Slider           0           0          0          0
# 40688        Curveball           0           0          0          0
# 40689  4-Seam Fastball           2           5          5          2
# 40690           Slider           2           5          5          2
#
#                          pitch_sequence
# 0              [FC, FC, SI, SI, FC, SI]
# 1                      [FF, FF, SL, SL]
# 2                  [SL, SL, FF, CH, FF]
# 3          [FF, SL, SL, FF, FF, SL, FF]
# 4                  [FF, FF, SL, FF, SL]
# ...                                 ...
# 40686              [FF, CH, FF, CH, SL]
# 40687          [SL, FF, FF, SL, FF, SL]
# 40688                  [CU, CH, CH, CU]
# 40689          [SL, SL, FF, FF, CH, FF]
# 40690  [SL, SL, FF, FF, SL, SL, SL, SL]
#
# [40691 rows x 29 columns]

# %%
statcast_data_grouped['description'].value_counts()
# Out:
# swinging_strike            25571
# called_strike               9148
# swinging_strike_blocked     3221
# foul_tip                    2716
# foul_bunt                     30
# missed_bunt                    4
# bunt_foul_tip                  1
# Name: description, dtype: int64

# %%
statcast_data_grouped.columns
# Out:
# Index(['game_pk', 'pitcher', 'at_bat_number', 'pitch_number', 'pitch_type',
#        'game_date', 'player_name', 'batter', 'events', 'description', 'stand',
#        'p_throws', 'home_team', 'away_team', 'type', 'balls', 'strikes',
#        'game_year', 'outs_when_up', 'inning', 'inning_topbot', 'fielder_2',
#        'pitcher.1', 'pitch_name', 'home_score', 'away_score', 'bat_score',
#        'fld_score', 'pitch_sequence'],
#       dtype='object')

# %%
final_drop_cols = ['pitch_type', 'game_date', 'player_name', 'at_bat_number',
                   'description', 'home_team', 'away_team', 'type', 'game_year',
                   'inning_topbot', 'pitcher.1', 'pitch_name', 'home_score',
                   'away_score']
pitch_seq_final = statcast_data_grouped.drop(columns=final_drop_cols)
pitch_seq_final
# Out:
#        game_pk  pitcher  pitch_number  batter     events stand p_throws  \
# 0       661032   571901             6  595978  strikeout     R        L
# 1       661032   628452             4  614177  strikeout     R        R
# 2       661032   628452             5  680911  strikeout     R        R
# 3       661032   660853             7  621493  strikeout     R        R
# 4       661032   663474             5  545361  strikeout     R        R
# ...        ...      ...           ...     ...        ...   ...      ...
# 40686   663463   669145             5  596142  strikeout     R        L
# 40687   663463   669145             6  596146  strikeout     L        L
# 40688   663463   669145             4  665482  strikeout     R        L
# 40689   663463   669211             6  596142  strikeout     R        L
# 40690   663463   669211             8  663616  strikeout     L        L
#
#        balls  strikes  outs_when_up  inning  fielder_2  bat_score  fld_score  \
# 0          2        2             1       8     435559          0          4
# 1          1        2             1       9     435559          1          4
# 2          1        2             2       9     435559          1          4
# 3          3        2             2       7     595978          4          0
# 4          1        2             2       1     595978          0          0
# ...      ...      ...           ...     ...        ...        ...        ...
# 40686      1        2             1       2     621532          0          0
# 40687      2        2             2       2     621532          0          0
# 40688      1        2             1       3     621532          0          0
# 40689      0        2             0       8     621532          5          2
# 40690      3        2             1       8     621532          5          2
#
#                          pitch_sequence
# 0              [FC, FC, SI, SI, FC, SI]
# 1                      [FF, FF, SL, SL]
# 2                  [SL, SL, FF, CH, FF]
# 3          [FF, SL, SL, FF, FF, SL, FF]
# 4                  [FF, FF, SL, FF, SL]
# ...                                 ...
# 40686              [FF, CH, FF, CH, SL]
# 40687          [SL, FF, FF, SL, FF, SL]
# 40688                  [CU, CH, CH, CU]
# 40689          [SL, SL, FF, FF, CH, FF]
# 40690  [SL, SL, FF, FF, SL, SL, SL, SL]
#
# [40691 rows x 15 columns]
